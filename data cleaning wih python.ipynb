# %%
import numpy as np
import pandas as pd
df=df = pd.read_excel (r'C:\Users\regent\Desktop\areej_029\COVID_FINAL_DATA.xlsx')# to get the datset
df.head() # loading datset
# Out:
#    Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0           4          48                          2
# 1           5          61                          0
# 2           6          84                         14
# 3           7          20                          0
# 4           8           3                          0
#
#    Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                           80  2020-03-11 00:00:00           0        0
# 1                           95  2020-03-11 00:00:00           0        0
# 2                          171  2020-03-11 00:00:00           1        0
# 3                           28  2020-03-11 00:00:00           0        0
# 4                            0  2020-03-11 00:00:00           0        0
#
#    Home Quarantine  New  (last 24 hrs)  Region  Still admitted  \
# 0              NaN                   3     ICT               2
# 1              NaN                   6  Punjab               0
# ...

# %%
df.isnull().any() # to check which column has null values
# Out:
# Unnamed: 0                           False
# Cumulative                           False
# Cumulative  Test positive            False
# Cumulative  tests performed          False
# Date                                 False
# Discharged                           False
# Expired                              False
# Home Quarantine                       True
# New  (last 24 hrs)                   False
# Region                               False
# Still admitted                       False
# Tests  performed in last 24 hours    False
# dtype: bool

# %%
df.isnull().sum()# to check how many null values are in each column
# Out:
# Unnamed: 0                             0
# Cumulative                             0
# Cumulative  Test positive              0
# Cumulative  tests performed            0
# Date                                   0
# Discharged                             0
# Expired                                0
# Home Quarantine                      139
# New  (last 24 hrs)                     0
# Region                                 0
# Still admitted                         0
# Tests  performed in last 24 hours      0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df2=df.copy() # replacing NAN with 0(IN COLUMN "HOME QURANTINE")
df3=df2.fillna(0)
df3
# Out:
#      Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0             4          48                          2
# 1             5          61                          0
# 2             6          84                         14
# 3             7          20                          0
# 4             8           3                          0
# ..          ...         ...                        ...
# 358           8        3933                        330
# 359           9        9705                        297
# 360          10       15540                       2160
# 361          11       47151                       5827
# 362          13       48061                       5291
#
#      Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                             80  2020-03-11 00:00:00           0        0
# 1                             95  2020-03-11 00:00:00           0        0
# 2                            171  2020-03-11 00:00:00           1        0
# ...

# %%
df3.isnull().values.any() # verify if we still have NAN values
# Out:
# False

# %%
print(df3) # datset is loaded,now we have no column that has NAN value
# Out:
#      Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0             4          48                          2
# 1             5          61                          0
# 2             6          84                         14
# 3             7          20                          0
# 4             8           3                          0
# ..          ...         ...                        ...
# 358           8        3933                        330
# 359           9        9705                        297
# 360          10       15540                       2160
# 361          11       47151                       5827
# 362          13       48061                       5291
#
#      Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                             80  2020-03-11 00:00:00           0        0
# 1                             95  2020-03-11 00:00:00           0        0
# 2                            171  2020-03-11 00:00:00           1        0
# ...

# %%
writer=pd.ExcelWriter('cleaned.xlsx')# SAVE cleaned dataset 
df3.to_excel(writer,'CORONA_CLEANED_DATASET')
writer.save()

# %%
# Out:
#      Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0             4          48                          2
# 1             5          61                          0
# 2             6          84                         14
# 3             7          20                          0
# 4             8           3                          0
# ..          ...         ...                        ...
# 358           8        3933                        330
# 359           9        9705                        297
# 360          10       15540                       2160
# 361          11       47151                       5827
# 362          13       48061                       5291
#
#      Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                             80  2020-03-11 00:00:00           0        0
# 1                             95  2020-03-11 00:00:00           0        0
# 2                            171  2020-03-11 00:00:00           1        0
# ...

# %%
print(df3)
# Out:
#      Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0             4          48                          2
# 1             5          61                          0
# 2             6          84                         14
# 3             7          20                          0
# 4             8           3                          0
# ..          ...         ...                        ...
# 358           8        3933                        330
# 359           9        9705                        297
# 360          10       15540                       2160
# 361          11       47151                       5827
# 362          13       48061                       5291
#
#      Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                             80  2020-03-11 00:00:00           0        0
# 1                             95  2020-03-11 00:00:00           0        0
# 2                            171  2020-03-11 00:00:00           1        0
# ...
